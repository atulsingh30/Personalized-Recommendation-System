# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use("ggplot")

import sklearn
from sklearn.decomposition import TruncatedSVD

# %%
flipkart_ratings = pd.read_csv('ratings_Beauty.csv')
flipkart_ratings = flipkart_ratings.dropna()
flipkart_ratings.head(20)
# Out:
#             UserId   ProductId  Rating   Timestamp
# 0   A39HTATAQ9V7YF  0205616461     5.0  1369699200
# 1   A3JM6GV9MNOF9X  0558925278     3.0  1355443200
# 2   A1Z513UWSAAO0F  0558925278     5.0  1404691200
# 3   A1WMRR494NWEWV  0733001998     4.0  1382572800
# 4   A3IAAVS479H7M7  0737104473     1.0  1274227200
# 5    AKJHHD5VEH7VG  0762451459     5.0  1404518400
# 6   A1BG8QW55XHN6U  1304139212     5.0  1371945600
# 7   A22VW0P4VZHDE3  1304139220     5.0  1373068800
# 8   A3V3RE4132GKRO  130414089X     5.0  1401840000
# 9   A327B0I7CYTEJC  130414643X     4.0  1389052800
# 10  A1BG8QW55XHN6U  130414643X     5.0  1372032000
# 11   AIFAAVTUYHEHB  130414643X     4.0  1378252800
# 12   AVOGV98AYOFG2  1304146537     5.0  1372118400
# 13  A22VW0P4VZHDE3  130414674X     5.0  1371686400
# 14   AVOGV98AYOFG2  1304168522     5.0  1372118400
# 15   A6R426V4J7AOM  1304168522     5.0  1373414400
# 16  A22VW0P4VZHDE3  1304174778     5.0  1372896000
# ...

# %%
flipkart_ratings.shape
# Out:
# (2023070, 4)

# %%
popular_products = pd.DataFrame(flipkart_ratings.groupby('ProductId')['Rating'].count())
most_popular = popular_products.sort_values('Rating', ascending=False)
most_popular.head(10)
# Out:
#             Rating
# ProductId
# B001MA0QY2    7533
# B0009V1YR8    2869
# B0043OYFKU    2477
# B0000YUXI0    2143
# B003V265QW    2088
# B000ZMBSPE    2041
# B003BQ6QXK    1918
# B004OHQR1Q    1885
# B00121UVU0    1838
# B000FS05VG    1589

# %%
most_popular.head(30).plot(kind = "bar")
# Out:
# <AxesSubplot:xlabel='ProductId'>

# %%
popular_products_by_userid = pd.DataFrame(flipkart_ratings.groupby('UserId')['Rating'].count())
most_popular_by_user = popular_products_by_userid.sort_values('Rating', ascending=False)
most_popular_by_user.head(10)
# Out:
#                 Rating
# UserId
# A3KEZLJ59C1JVH     389
# A281NPSIMI1C2R     336
# A3M174IC0VXOS2     326
# A2V5R832QCSOMX     278
# A3LJLRIZL38GG3     276
# ALQGOMOY1F5X9      275
# AKMEY1BSHSDG7      269
# A3R9H6OKZHHRJD     259
# A1M04H40ZVGWVG     249
# A1RRMZKOMZ2M7J     225

# %%
most_popular_by_user.head(30).plot(kind = "bar",color=['Blue'])
# Out:
# <AxesSubplot:xlabel='UserId'>

# %%
flipkart_ratings1 = flipkart_ratings.head(10000)

# %%
ratings_utility_matrix = flipkart_ratings1.pivot_table(values='Rating', index='UserId', columns='ProductId', fill_value=0)
ratings_utility_matrix.head()
# Out:
# ProductId              0205616461  0558925278  0733001998  0737104473  \
# UserId
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A03056581JJIOL5FSKJY7           0           0           0           0
# A03099101ZRK4K607JVHH           0           0           0           0
# A0505229A7NSH3FRXRR4            0           0           0           0
#
# ProductId              0762451459  1304139212  1304139220  130414089X  \
# UserId
# A00205921JHJK5X9LNP42           0           0           0           0
# A024581134CV80ZBLIZTZ           0           0           0           0
# A03056581JJIOL5FSKJY7           0           0           0           0
# A03099101ZRK4K607JVHH           0           0           0           0
# A0505229A7NSH3FRXRR4            0           0           0           0
#
# ProductId              130414643X  1304146537  ...  B000052YPE  B000052YPF  \
# ...

# %%
ratings_utility_matrix.shape
# Out:
# (9697, 886)

# %%
X = ratings_utility_matrix.T
X.head()
# Out:
# UserId      A00205921JHJK5X9LNP42  A024581134CV80ZBLIZTZ  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# 0737104473                      0                      0
# 0762451459                      0                      0
#
# UserId      A03056581JJIOL5FSKJY7  A03099101ZRK4K607JVHH  \
# ProductId
# 0205616461                      0                      0
# 0558925278                      0                      0
# 0733001998                      0                      0
# 0737104473                      0                      0
# 0762451459                      0                      0
#
# UserId      A0505229A7NSH3FRXRR4  A05492663T95KW63BR75K  \
# ProductId
# 0205616461                     0                      0
# 0558925278                     0                      0
# 0733001998                     0                      0
# ...

# %%
X.shape
# Out:
# (886, 9697)

# %%
X1 = X

# %%
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (886, 10)

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (886, 886)

# %%
X.index[9]
# Out:
# '1304146537'

# %%
i = "1304146537"

product_names = list(X.index)
product_ID = product_names.index(i)
product_ID
# Out:
# 9

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (886,)

# %%
user = "1304146537"
print('Top 10 recommended products for the user:',user ,":")
Recommend = list(X.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(i) 

Recommend[0:9]
# Out:
# Top 10 recommended products for the user: 1304146537 :
# ['1304168522',
#  '1304482596',
#  '1304488608',
#  '1304495396',
#  '1304511073',
#  '1304511081',
#  '130451112X',
#  '1304511138',
#  '1304511146']
